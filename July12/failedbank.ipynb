# %%
import numpy as np # type: ignore
import pandas as pd # type: ignore
import matplotlib.pyplot as plt # type: ignore
import seaborn as sns # type: ignore

# %%
failedbank = pd.read_html("https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/") # type: ignore
failedbank
# Out:
# [                             Bank NameBank       CityCity StateSt  CertCert  \
#  0    Republic First Bank dba Republic Bank   Philadelphia      PA     27332
#  1                            Citizens Bank       Sac City      IA      8758
#  2                 Heartland Tri-State Bank        Elkhart      KS     25851
#  3                      First Republic Bank  San Francisco      CA     59017
#  4                           Signature Bank       New York      NY     57053
#  ..                                     ...            ...     ...       ...
#  564                     Superior Bank, FSB       Hinsdale      IL     32646
#  565                    Malta National Bank          Malta      OH      6629
#  566        First Alliance Bank & Trust Co.     Manchester      NH     34264
#  567      National State Bank of Metropolis     Metropolis      IL      3815
#  568                       Bank of Honolulu       Honolulu      HI     21029
#
# ...

# %%
type(failedbank)
# Out:
# list

# %%
len(failedbank)
# Out:
# 1

# %%
for fb in failedbank:
    print(fb)
# Out:
#                              Bank NameBank       CityCity StateSt  CertCert  \
# 0    Republic First Bank dba Republic Bank   Philadelphia      PA     27332
# 1                            Citizens Bank       Sac City      IA      8758
# 2                 Heartland Tri-State Bank        Elkhart      KS     25851
# 3                      First Republic Bank  San Francisco      CA     59017
# 4                           Signature Bank       New York      NY     57053
# ..                                     ...            ...     ...       ...
# 564                     Superior Bank, FSB       Hinsdale      IL     32646
# 565                    Malta National Bank          Malta      OH      6629
# 566        First Alliance Bank & Trust Co.     Manchester      NH     34264
# 567      National State Bank of Metropolis     Metropolis      IL      3815
# 568                       Bank of Honolulu       Honolulu      HI     21029
#
# ...

# %%
failedbank[0]
# Out:
#                              Bank NameBank       CityCity StateSt  CertCert  \
# 0    Republic First Bank dba Republic Bank   Philadelphia      PA     27332
# 1                            Citizens Bank       Sac City      IA      8758
# 2                 Heartland Tri-State Bank        Elkhart      KS     25851
# 3                      First Republic Bank  San Francisco      CA     59017
# 4                           Signature Bank       New York      NY     57053
# ..                                     ...            ...     ...       ...
# 564                     Superior Bank, FSB       Hinsdale      IL     32646
# 565                    Malta National Bank          Malta      OH      6629
# 566        First Alliance Bank & Trust Co.     Manchester      NH     34264
# 567      National State Bank of Metropolis     Metropolis      IL      3815
# 568                       Bank of Honolulu       Honolulu      HI     21029
#
# ...

# %%
failedbank[0].head(20)
# Out:
#                                         Bank NameBank            CityCity  \
# 0               Republic First Bank dba Republic Bank        Philadelphia
# 1                                       Citizens Bank            Sac City
# 2                            Heartland Tri-State Bank             Elkhart
# 3                                 First Republic Bank       San Francisco
# 4                                      Signature Bank            New York
# 5                                 Silicon Valley Bank         Santa Clara
# 6                                   Almena State Bank              Almena
# 7                          First City Bank of Florida   Fort Walton Beach
# 8                                The First State Bank       Barboursville
# 9                                  Ericson State Bank             Ericson
# 10                   City National Bank of New Jersey              Newark
# 11                                      Resolute Bank              Maumee
# ...

# %%
failedbank[0].tail(20)
# Out:
#                               Bank NameBank         CityCity StateSt  \
# 549                    Pulaski Savings Bank     Philadelphia      PA
# 550   First National Bank of Blanchardville   Blanchardville      WI
# 551                   Southern Pacific Bank         Torrance      CA
# 552             Farmers Bank of Cheneyville      Cheneyville      LA
# 553                           Bank of Alamo            Alamo      TN
# 554  AmTrade International Bank  En Español          Atlanta      GA
# 555          Universal Federal Savings Bank          Chicago      IL
# 556            Connecticut Bank of Commerce         Stamford      CT
# 557                        New Century Bank  Shelby Township      MI
# 558                   Net 1st National Bank       Boca Raton      FL
# 559                            NextBank, NA          Phoenix      AZ
# 560                Oakwood Deposit Bank Co.          Oakwood      OH
# 561                   Bank of Sierra Blanca    Sierra Blanca      TX
# ...

# %%
failedbank[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Bank NameBank            569 non-null    object
#  1   CityCity                 569 non-null    object
#  2   StateSt                  569 non-null    object
#  3   CertCert                 569 non-null    int64
#  4   Acquiring InstitutionAI  569 non-null    object
#  5   Closing DateClosing      569 non-null    object
#  6   FundFund                 569 non-null    int64
# dtypes: int64(2), object(5)
# memory usage: 31.2+ KB

# %%
failedbank[0].memory_usage()
# Out:
# Index                       132
# Bank NameBank              4552
# CityCity                   4552
# StateSt                    4552
# CertCert                   4552
# Acquiring InstitutionAI    4552
# Closing DateClosing        4552
# FundFund                   4552
# dtype: int64
